# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pylab import *

# %%
# matplotlib.rcParams.update({'font.size': 25})
# matplotlib.rcParams['text.usetex'] = True
# ax = plt.subplot(1,1,1)
# #legend
# ax.legend(['1st-order', '2nd-order','3rd-order'], fontsize=20, loc='upper left', frameon=False, ncol=3, labelspacing=0, 
#           columnspacing=0.3, borderpad = 0.3, handletextpad=0.3) #bbox_to_anchor=(0, 1.3),

# %%
# raw_data = {'K': ['5', '10', '15'],   
#         'First': [.0078, .35, .00],
#         'Second': [.0115, .30, .00],
#         'Third': [.00, .5, .00]}

# raw_data = {'K': ['5', '10', '15'],   
#         'First': [.9, .9, .9],
#         'Second': [.85, .8, .8],
#         'Third': [.5, .4, .4]}


raw_data = {'K': ['5', '10', '15'],   
        'First': [.86, .7, .63],
        'Second': [.83, .7, .73],
        'Third': [.69, .66, .63]}


df = pd.DataFrame(raw_data, columns = ['K', 'First', 'Second','Third'])
df
# Out:
#     K  First  Second  Third
# 0   5   0.86    0.83   0.69
# 1  10   0.70    0.70   0.66
# 2  15   0.63    0.73   0.63

# %%
matplotlib.rcParams.update({'font.size': 25})
# plt.rcParams["figure.figsize"] = (20,3)

matplotlib.rcParams['text.usetex'] = True
ax = plt.subplot(1,1,1)

# Setting the positions and width for the bars
pos = list(range(len(df['K']))) 
print(pos)
width = 0.15

ax.bar([p - 1*width for p in pos], 
        #using df['post_score'] data,
        df['First'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=1, 
        # with color
        color='black', 
        # with label the third value in first_name
        label=df['K'],
        edgecolor='black', 
        hatch='') 

ax.bar([p - 0*width for p in pos], 
        #using df['post_score'] data,
        df['Second'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=1, 
        # with color
        color='white', 
        # with label the third value in first_name
        label=df['K'],
        edgecolor='black', 
        hatch='.') 

ax.bar([p + 1*width for p in pos], 
        #using df['post_score'] data,
        df['Third'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=1, 
        # with color
        color='white', 
        # with label the third value in first_name
        label=df['K'],
        edgecolor='black', 
        hatch='\\')




xlabel('Techniques')
# ylabel('Functional error')
ylabel('Accuracy')

# ylabel('\#Users') #'Users who tweet/retweet rumors'
# plt.title('Uniform dataset', loc='left', color='black', fontsize=28)
# plt.grid(True,axis='y',alpha=0.5)

# Styling for y-ax
#plt.ylim([0, 100])
# plt.xlim([0, 100])
# Styling for x-ax
ax.set_xticks(pos)
ax.set_xticklabels(['Our', 'Corr', 'TANE'])

# To specify the number of ticks on both or any single axes
# plt.yticks(np.arange(0, 1.15, 0.2))
plt.yticks(np.arange(0, 1.1, 0.2))


#legend
# ax.legend(['1st-order', '2nd-order','3rd-order'], fontsize=20, loc='upper left', frameon=False, ncol=3, labelspacing=0, 
#           columnspacing=0.9, borderpad = 0.3, handletextpad=0.3) #bbox_to_anchor=(0, 1.3), 


#Save file
# dir = "../tex/figures/"
# plt.savefig("order_uniform.png", bbox_inches='tight', dpi=500)
plt.show()
# Out:
# [0, 1, 2, 3]

# %%
raw_data = {'K': ['5', '10', '15'],   
        'First': [.86, .73, .63],
        'Second': [.8, .73, .63],
        'Third': [.72, .66, .66]}
df = pd.DataFrame(raw_data, columns = ['K', 'First', 'Second','Third'])


matplotlib.rcParams.update({'font.size': 25})
matplotlib.rcParams['text.usetex'] = True
ax = plt.subplot(1,1,1)

# Setting the positions and width for the bars
pos = list(range(len(df['K']))) 
print(pos)
width = 0.15


ax.bar([p - 1*width for p in pos], 
        #using df['post_score'] data,
        df['First'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=1, 
        # with color
        color='black', 
        # with label the third value in first_name
        label=df['K'],
        edgecolor='black', 
        hatch='') 

# ax.bar([p - 0*width for p in pos], 
#         #using df['post_score'] data,
#         df['Second'], 
#         # of width
#         width, 
#         # with alpha 0.5
#         alpha=1, 
#         # with color
#         color='white', 
#         # with label the third value in first_name
#         label=df['K'],
#         edgecolor='black', 
#         hatch='.') 

# ax.bar([p + 1*width for p in pos], 
#         #using df['post_score'] data,
#         df['Third'], 
#         # of width
#         width, 
#         # with alpha 0.5
#         alpha=1, 
#         # with color
#         color='white', 
#         # with label the third value in first_name
#         label=df['K'],
#         edgecolor='black', 
#         hatch='\\')

# xlabel('Techniques')
# # ylabel('Functional error')
# ylabel('Accuracy')

# # ylabel('\#Users') #'Users who tweet/retweet rumors'
# # plt.title('tpc\_h dataset', loc='left', color='black', fontsize=28)
# # plt.title('Gauss dataset', loc='left', color='black', fontsize=28)

# plt.grid(True,axis='y',alpha=0.5)

# # Styling for y-ax
# #plt.ylim([0, 100])

# # Styling for x-ax
# ax.set_xticks(pos)
# ax.set_xticklabels(['Our', 'Corr', 'TANE'])

# # To specify the number of ticks on both or any single axes
# # plt.yticks(np.arange(0, 1.15, 0.2))
# plt.yticks(np.arange(0, 1.1, 0.2))

# #legend
# # ax.legend(['1st-order', '2nd-order','3rd-order'], fontsize=20, loc='upper left', frameon=False, ncol=2, labelspacing=0, 
# #           columnspacing=0.3, borderpad = 0.3, handletextpad=0.3) #bbox_to_anchor=(0, 1.3), 


# #Save file
# # dir = "../tex/figures/"
plt.savefig("order_gauss.png", bbox_inches='tight', dpi=300)
# Out:
# [0, 1, 2]

# %%
raw_data = {'K': ['5', '10', '15'],   
        'First': [.93, .9, .7],
        'Second': [.9, .7, .66],
        'Third': [.83, .66, .6]}
df = pd.DataFrame(raw_data, columns = ['K', 'First', 'Second','Third'])


matplotlib.rcParams.update({'font.size': 25})
matplotlib.rcParams['text.usetex'] = True
ax = plt.subplot(1,1,1)

# Setting the positions and width for the bars
pos = list(range(len(df['K']))) 
print(pos)
width = 0.15


ax.bar([p - 1*width for p in pos], 
        #using df['post_score'] data,
        df['First'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=1, 
        # with color
        color='black', 
        # with label the third value in first_name
        label=df['K'],
        edgecolor='black', 
        hatch='') 

ax.bar([p - 0*width for p in pos], 
        #using df['post_score'] data,
        df['Second'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=1, 
        # with color
        color='white', 
        # with label the third value in first_name
        label=df['K'],
        edgecolor='black', 
        hatch='.') 

ax.bar([p + 1*width for p in pos], 
        #using df['post_score'] data,
        df['Third'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=1, 
        # with color
        color='white', 
        # with label the third value in first_name
        label=df['K'],
        edgecolor='black', 
        hatch='\\')

xlabel('Techniques')
# ylabel('Functional error')
ylabel('Accuracy')

# ylabel('\#Users') #'Users who tweet/retweet rumors'
# plt.title('tpc\_ds dataset', loc='left', color='black', fontsize=28)
# plt.title('Logtail dataset', loc='left', color='black', fontsize=28)

plt.grid(True,axis='y',alpha=0.5)

# Styling for y-ax
#plt.ylim([0, 100])

# Styling for x-ax
ax.set_xticks(pos)
ax.set_xticklabels(['Our', 'Corr', 'TANE'])

# To specify the number of ticks on both or any single axes
# plt.yticks(np.arange(0, 1.15, 0.2))
plt.yticks(np.arange(0, 1.1, 0.2))

#legend
# ax.legend(['1st-order', '2nd-order','3rd-order'], fontsize=20, loc='upper left', frameon=False, ncol=2, labelspacing=0, 
#           columnspacing=0.3, borderpad = 0.3, handletextpad=0.3) #bbox_to_anchor=(0, 1.3), 


#Save file
# dir = "../tex/figures/"
plt.savefig("order_longtail.png", bbox_inches='tight', dpi=300)
# Out:
# [0, 1, 2]

# %%
raw_data = {'K': ['5', '10', '15'],   
        'First': [.96, .83, .66],
        'Second': [.96, .8, .6],
        'Third': [.72, .66, .56]}
df = pd.DataFrame(raw_data, columns = ['K', 'First', 'Second','Third'])


matplotlib.rcParams.update({'font.size': 25})
matplotlib.rcParams['text.usetex'] = True
ax = plt.subplot(1,1,1)

# Setting the positions and width for the bars
pos = list(range(len(df['K']))) 
print(pos)
width = 0.15


ax.bar([p - 1*width for p in pos], 
        #using df['post_score'] data,
        df['First'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=1, 
        # with color
        color='black', 
        # with label the third value in first_name
        label=df['K'],
        edgecolor='black', 
        hatch='') 

ax.bar([p - 0*width for p in pos], 
        #using df['post_score'] data,
        df['Second'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=1, 
        # with color
        color='white', 
        # with label the third value in first_name
        label=df['K'],
        edgecolor='black', 
        hatch='.') 

ax.bar([p + 1*width for p in pos], 
        #using df['post_score'] data,
        df['Third'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=1, 
        # with color
        color='white', 
        # with label the third value in first_name
        label=df['K'],
        edgecolor='black', 
        hatch='\\')

xlabel('Techniques')
# ylabel('Functional error')
ylabel('Accuracy')

# ylabel('\#Users') #'Users who tweet/retweet rumors'
# plt.title('uce dataset', loc='left', color='black', fontsize=28)
# plt.title('Logarithm dataset', loc='left', color='black', fontsize=28)

plt.grid(True,axis='y',alpha=0.5)

# Styling for y-ax
#plt.ylim([0, 100])

# Styling for x-ax
ax.set_xticks(pos)
ax.set_xticklabels(['Our', 'Corr', 'FD'])

# To specify the number of ticks on both or any single axes
# plt.yticks(np.arange(0, 1.15, 0.2))
plt.yticks(np.arange(0, 1.1, 0.2))

#legend
# ax.legend(['1st-order', '2nd-order','3rd-order'], fontsize=20, loc='upper left', frameon=False, ncol=2, labelspacing=0, 
#           columnspacing=0.3, borderpad = 0.3, handletextpad=0.3) #bbox_to_anchor=(0, 1.3), 


#Save file
# dir = "../tex/figures/"
plt.savefig("order_log.png", bbox_inches='tight', dpi=300)
# Out:
# [0, 1, 2]

# %% [markdown]
# # Data type

# %%
# ax.set_xticklabels(['Continous', 'Ordinal', 'Categorical','Binary'])

# raw_data = {'K': ['5', '10', '15','20'],   
#         'First': [.00, .83, .17,0.13],# our
#         'Second': [.7, .71, .7,0.83], # corr
#         'Third': [.7, .7, .73,0.73]}# tane

raw_data = {'K': ['5', '10', '15','20'],   
        'First': [.86, .83, .77,0.9],# our
        'Second': [.7, .71, .7,0.83], # corr
        'Third': [.7, .7, .73,0.73]}# tane
df = pd.DataFrame(raw_data, columns = ['K', 'First', 'Second','Third'])


matplotlib.rcParams.update({'font.size': 25})
matplotlib.rcParams['text.usetex'] = True
ax = plt.subplot(1,1,1)

# Setting the positions and width for the bars
pos = list(range(len(df['K']))) 
print(pos)
width = 0.15


ax.bar([p - 1*width for p in pos], 
        #using df['post_score'] data,
        df['First'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=1, 
        # with color
        color='black', 
        # with label the third value in first_name
        label=df['K'],
        edgecolor='black', 
        hatch='') 

ax.bar([p - 0*width for p in pos], 
        #using df['post_score'] data,
        df['Second'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=1, 
        # with color
        color='white', 
        # with label the third value in first_name
        label=df['K'],
        edgecolor='black', 
        hatch='.') 

ax.bar([p + 1*width for p in pos], 
        #using df['post_score'] data,
        df['Third'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=1, 
        # with color
        color='white', 
        # with label the third value in first_name
        label=df['K'],
        edgecolor='black', 
        hatch='\\')


xlabel('Techniques')
# ylabel('Functional error')
ylabel('Accuracy')

# ylabel('\#Users') #'Users who tweet/retweet rumors'
# plt.title('tpc\_h dataset', loc='left', color='black', fontsize=28)
# plt.title('Gauss dataset', loc='left', color='black', fontsize=28)

plt.grid(True,axis='y',alpha=0.5)

# Styling for y-ax
#plt.ylim([0, 100])

# Styling for x-ax
ax.set_xticks(pos)
ax.set_xticklabels(['Continuous', 'Ordinal', 'Categorical','Binary'])

# To specify the number of ticks on both or any single axes
# plt.yticks(np.arange(0, 1.15, 0.2))
plt.yticks(np.arange(0, 1.1, 0.2))

#legend
# ax.legend(['Our', 'Corr','TANE'], fontsize=20, loc='upper left', frameon=False, ncol=3, labelspacing=0, 
#           columnspacing=0.3, borderpad = 0.3, handletextpad=0.3) #bbox_to_anchor=(0, 1.3), 
plt.setp(ax.get_xticklabels(), rotation=20, ha="center",
             rotation_mode="anchor",fontsize=23)

#Save file
# dir = "../tex/figures/"
plt.savefig("data_type.png", bbox_inches='tight', dpi=300)
plt.show()
# Out:
# [0, 1, 2, 3]
